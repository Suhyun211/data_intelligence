# %% [markdown]
# <h1>SVM과 인공신경망</h1>

# %%
# libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # SVM

# %% [markdown]
# 이진화된 당뇨 데이터 셋

# %%
from sklearn.datasets import load_diabetes
X, y_numeric = load_diabetes(return_X_y=True,as_frame=True)
y = [ 'Neg' if y_numeric[i]<140 else 'Pos' for i in range(len(y_numeric)) ]
xtrain, xtest, ytrain, ytest = train_test_split(X,y,test_size=0.4,random_state=42)

# %% [markdown]
# 다항 커널을 이용한 SVM

# %%
from sklearn.svm import SVC
f = SVC(C=5,kernel='poly',degree=3)
f.fit(xtrain,ytrain)
# Out:
# SVC(C=5, kernel='poly')

# %%
print( f.score(xtrain,ytrain), f.score(xtest,ytest) )
# Out:
# 0.8452830188679246 0.7570621468926554

# %% [markdown]
# RBF를 이용한 SVM

# %%
# parameter tuning
params = 10**np.linspace(-5,5,num=31)
acc_train = []; acc_cv = []; acc_test = []
for c in params:
    f = SVC(C=c,kernel='rbf',gamma='auto',random_state=0)
    f.fit(xtrain,ytrain)
    acc_train.append( f.score(xtrain,ytrain) )
    acc_cv.append( cross_val_score(f,xtrain,ytrain,cv=5).mean() )
    acc_test.append( f.score(xtest,ytest) )

# %%
idx = np.log10(params)
plt.plot(idx,acc_train,idx,acc_cv,idx,acc_test)
plt.legend(['Train','CV','Test'])

# %%
from sklearn.model_selection import GridSearchCV
params = {'C': 10**np.linspace(-1,5,21),}
f = GridSearchCV( SVC(kernel='rbf',gamma='auto'), params )
f.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=SVC(gamma='auto'),
#              param_grid={'C': array([1.00000000e-01, 1.99526231e-01, 3.98107171e-01, 7.94328235e-01,
#        1.58489319e+00, 3.16227766e+00, 6.30957344e+00, 1.25892541e+01,
#        2.51188643e+01, 5.01187234e+01, 1.00000000e+02, 1.99526231e+02,
#        3.98107171e+02, 7.94328235e+02, 1.58489319e+03, 3.16227766e+03,
#        6.30957344e+03, 1.25892541e+04, 2.51188643e+04, 5.01187234e+04,
#        1.00000000e+05])})

# %%
f.best_params_
# Out:
# {'C': np.float64(12.589254117941675)}

# %%
print( f.score(xtrain,ytrain), f.score(xtest,ytest) )
# Out:
# 0.720754716981132 0.8022598870056498

# %% [markdown]
# # 인공신경망

# %% [markdown]
# 이진화된 당뇨 데이터 셋

# %%
from sklearn.datasets import load_diabetes
X, y_numeric = load_diabetes(return_X_y=True,as_frame=True)
y = [ 'Neg' if y_numeric[i]<140 else 'Pos' for i in range(len(y_numeric)) ]
xtrain, xtest, ytrain, ytest = train_test_split(X,y,test_size=0.4,random_state=42)

# %% [markdown]
# 인공신경망 (분류 모델, 이진분류)

# %%
from sklearn.neural_network import MLPClassifier
f = MLPClassifier(
        hidden_layer_sizes = (2,2),
        activation = 'logistic',
        solver = 'lbfgs', # for small data set, sgd/adam for large data set
        alpha = 0.001, # L2 regularization
        batch_size = 'auto',
        learning_rate = 'constant',
        learning_rate_init = 0.001,
        random_state = 0,
        max_iter = 10000)

# %%
f.fit(xtrain,ytrain)
# Out:
# MLPClassifier(activation='logistic', alpha=0.001, hidden_layer_sizes=(2, 2),
#               max_iter=10000, random_state=0, solver='lbfgs')

# %%
print( f.score(xtrain,ytrain), f.score(xtest,ytest) )
# Out:
# 0.5094339622641509 0.4971751412429379

# %%
f.coefs_
# Out:
# [array([[ 0.03984343,  0.17565562],
#         [ 0.0839064 ,  0.03665243],
#         [-0.06237327,  0.11898215],
#         [-0.05098735,  0.31977102],
#         [ 0.37856232, -0.09520096],
#         [ 0.23818025,  0.02356312],
#         [ 0.05558444,  0.347595  ],
#         [-0.35026679, -0.33719646],
#         [-0.39176645,  0.2714562 ],
#         [ 0.22708623,  0.30202552]]),
#  array([[-0.05313496,  0.39157514],
#         [-0.53840243,  0.19298804]]),
#  array([[0.13086647],
#         [0.09060609]])]

# %%
f.intercepts_
# Out:
# [array([0.38992741, 0.24352371]),
#  array([-0.50195794,  0.6201843 ]),
#  array([-0.06750068])]

# %%
from sklearn.neural_network import MLPClassifier
f = MLPClassifier(
        hidden_layer_sizes = (10,5),
        activation = 'logistic',
        solver = 'lbfgs', # for small data set, sgd/adam for large data set
        alpha = 0.01, # L2 regularization
        batch_size = 'auto',
        learning_rate = 'constant',
        learning_rate_init = 0.001,
        random_state = 0,
        max_iter = 10000)
f.fit(xtrain,ytrain)
print( f.score(xtrain,ytrain), f.score(xtest,ytest) )
# Out:
# 0.9962264150943396 0.7062146892655368

# %% [markdown]
# 인공신경망 (다중 분류)

# %%
from sklearn.datasets import load_diabetes
X, y_numeric = load_diabetes(return_X_y=True,as_frame=True)
y = pd.cut(y_numeric,bins=3,labels=[1,2,3])
xtrain, xtest, ytrain, ytest = train_test_split(X,y,test_size=0.4,random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
f = MLPClassifier(
        hidden_layer_sizes = (2,2),
        activation = 'logistic',
        solver = 'lbfgs', # for small data set, sgd/adam for large data set
        alpha = 0.001, # L2 regularization
        batch_size = 'auto',
        learning_rate = 'constant',
        learning_rate_init = 0.001,
        random_state = 0,
        max_iter = 10000)
f.fit(xtrain,ytrain)
print( f.score(xtrain,ytrain), f.score(xtest,ytest) )
# Out:
# 0.6867924528301886 0.6214689265536724

# %%
f.coefs_
# Out:
# [array([[-13.55142449, -15.22424965],
#         [  0.99103622, -11.59132317],
#         [ -0.37266659,  12.71209331],
#         [ -3.84219813,  16.14356959],
#         [ 10.98769878,  -8.731274  ],
#         [-11.22568554,  -5.98114604],
#         [ 15.13317332,   7.51020428],
#         [ -0.74542534,  10.28081463],
#         [ 13.40397791,  24.55631954],
#         [-23.6277976 , -24.26798341]]),
#  array([[ 38.84354138,  11.28180258],
#         [-10.46429723, -30.12189141]]),
#  array([[  7.28437446,   6.85972216, -14.24154617],
#         [  8.80869819,  -0.30075157,  -8.41053494]])]

# %% [markdown]
# # 연습 문제

# %% [markdown]
# 아래와 같이 MNIST 데이터 셋을 읽고 다음의 질문에 답하시오. MNIST 데이터 셋은 아래와 같이 읽도록 한다.
# 1. MNIST 데이터 셋의 샘플의 수는 몇 개인가? 총 변수의 수는 몇 개인가? 클래스의 수는 몇 개인가?
# 2. MNIST 데이터의 훈련 데이터를 이용하여 SVM 모델을 훈련하고, 평가 데이터에서 성능을 측정하시오.
# 3. MNIST 데이터의 훈련 데이터를 이용하여 인공신경망 모델을 훈련하고, 평가 데이터에서 성능을 측정하시오.

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
X, y = load_digits(return_X_y=True)
xtrain, xtest, ytrain, ytest = train_test_split(X,y,test_size=0.4,random_state=42)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X.shape, xtrain.shape, xtest.shape, ytest.shape
# Out:
# ((1797, 64), (1078, 64), (719, 64), (719,))

# %%
MAX = -1
MAX_COUNTER = -1
for i in range(10):
  print(i, len(ytrain[np.where(ytrain==i)]))
  if MAX_COUNTER < len(ytrain[np.where(ytrain==i)]):
    MAX = i
    MAX_COUNTER = len(ytrain[np.where(ytrain==i)])

print('가장 많은 수의 레이블 :',MAX, MAX_COUNTER)
# Out:
# 0 111
# 1 110
# 2 111
# 3 112
# 4 103
# 5 99
# 6 112
# 7 108
# 8 109
# 9 103
# 가장 많은 수의 레이블 : 3 112

# %%
len(set(y))
# Out:
# 10

# %%
# 총 샘플의 수 : 1797
# 총 변수의 수 : 64
# 클래스의 수 : 10
# 총 훈련데이터 샘플의 수 : 1078

# %%
plt.gray()
plt.imshow(xtrain[0].reshape((8,-1)))

# %%
from sklearn.svm import SVC
svc = SVC(C=5,kernel='poly',degree=3)
svc.fit(xtrain,ytrain)
svc_score = svc.score(xtest,ytest)
print(svc_score)
# Out:
# 0.9902642559109874

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(
        hidden_layer_sizes = (100,10),
        activation = 'logistic',
        solver = 'adam', # for small data set, sgd/adam for large data set
        alpha = 0.001, # L2 regularization
        batch_size = 'auto',
        learning_rate = 'constant',
        learning_rate_init = 0.001,
        random_state = 0,
        max_iter = 10000)
mlp.fit(xtrain,ytrain)
mlp_score = mlp.score(xtest,ytest)
print(mlp_score)
# Out:
# 0.9652294853963839
