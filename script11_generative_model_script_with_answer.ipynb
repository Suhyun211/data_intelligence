# %% [markdown]
# <h1>생성 모델</h1>

# %%
# 라이브러리
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# MNIST 데이터, 1D 데이터로 Flatten하여 사용
mnist = tf.keras.datasets.mnist
(xtrain,ytrain), (xtest,ytest) = mnist.load_data()
xtrain, xtest = xtrain/255.0, xtest/255.0
xtrain = xtrain.reshape( (len(xtrain), 28*28) )
xtest = xtest.reshape( (len(xtest), 28*28) )
print( xtrain.shape, xtest.shape )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# (60000, 784) (10000, 784)

# %% [markdown]
# # VAE

# %%
# 네트워크 파라메터
input_size = 784
n_hidden = 256
latent_size = 2

# %% [markdown]
# Encoder

# %%
# 샘플링 함수: N(m,v)에서 난수를 추출
def sampling(args):
    m, v = args  # v는 log(var)
    epsilon = tf.random.normal( shape=tf.shape(m) )
    return m + tf.math.exp(0.5 * v) * epsilon   # N(0,1) -> N(m,v)

# %%
input = tf.keras.Input(shape=(input_size,), name='input')
hidden = tf.keras.layers.Dense(
    n_hidden, activation='relu', name='hidden')(input)
z_mean = tf.keras.layers.Dense(latent_size, name='z_mean')(hidden)
z_var = tf.keras.layers.Dense(latent_size, name='z_var')(hidden)
z = tf.keras.layers.Lambda(sampling, name='z_sampling')([z_mean, z_var])
encoder = tf.keras.Model( input, [z_mean, z_var, z] )

# %%
encoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 784)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden (Dense)      │ (None, 256)       │    200,960 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │        514 │ hidden[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_var (Dense)       │ (None, 2)         │        514 │ hidden[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_sampling (Lambda) │ (None, 2)         │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_var[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 201,988 (789.02 KB)
#  Trainable params: 201,988 (789.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(encoder, show_shapes=True)

# %% [markdown]
# Decoder

# %%
# 디코더 입력은 latent 변수로부터
input = tf.keras.Input(shape=(latent_size,), name='input')
hidden = tf.keras.layers.Dense(
    n_hidden, activation='relu', name='hidden')(input)
# 출력은 인코더 입력과 같도록 학습하기 때문에 input_size가 사용
output = tf.keras.layers.Dense(
    input_size, activation='sigmoid',name='output')(hidden)
decoder = tf.keras.Model( input, output, name='decoder' )

# %%
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden (Dense)                  │ (None, 256)            │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 784)            │       201,488 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 202,256 (790.06 KB)
#  Trainable params: 202,256 (790.06 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(decoder, show_shapes=True)

# %% [markdown]
# VAE

# %%
input = tf.keras.Input(shape=(input_size,), name='input')
z = encoder(input)[2]  # [0]: z_mean, [1]: z_var, [2]: z
output = decoder(z)
model = tf.keras.Model(input, output, name='vae')

# %%
model.summary()
# Out:
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional (Functional)         │ [(None, 2), (None, 2), │       201,988 │
# │                                 │ (None, 2)]             │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 784)            │       202,256 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 404,244 (1.54 MB)
#  Trainable params: 404,244 (1.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# 훈련

# %%
# 훈련 파라메터
r_loss_factor = 1000

# %%
# 손실함수 정의
def vae_loss(x, recon_x):
  # 재구성을 위한 복원 손실
  m, v, z = encoder(x)
  recon_x = decoder(z)
  r_loss = tf.keras.losses.mse(x,recon_x)
  # 원하는 분포로 맞추기 위한 KL Divergence 손실
  # m = 0, v = log(var) = 0이 되면 최소
  kl_loss = 0.5*tf.reduce_sum(tf.square(m) + tf.exp(v) - v - 1, axis=1)
  return tf.reduce_mean(r_loss*r_loss_factor + kl_loss)

# %%
model.compile(optimizer='adam',loss=vae_loss)

# %%
model.fit( xtrain, xtrain, epochs=20 )
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 69.6116
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 53.5541
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 51.9548
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 50.9810
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 50.3585
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 49.9189
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 49.6213
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 49.2506
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 48.9485
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 48.7175
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 48.4544
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 48.3160
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 48.1147
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 48.0238
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 47.7899
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 47.8076
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 47.6507
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 47.5062
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 47.3583
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 47.2925

# %% [markdown]
# 복원 테스트

# %%
r_xtest = model.predict(xtest)
print("mse: ",np.array(tf.keras.losses.mse(xtest,r_xtest)).mean())
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# mse:  0.042906854

# %%
plt.figure(figsize=(4, 8))
ax = plt.subplot(1, 2, 1)
plt.imshow(xtest[0].reshape(28,28), vmin=0, vmax=1, cmap="gray")
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax = plt.subplot(1, 2, 2)
plt.imshow(r_xtest[0].reshape(28,28), vmin=0, vmax=1, cmap="gray")
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# 생성 테스트

# %%
# N(0,1)을 따르는 2차원 잠재변수를 입력으로
new = decoder(np.array([[0,0]]))
plt.figure(figsize=(4, 4))
plt.imshow(np.array(new[0]).reshape(28,28), vmin=0, vmax=1, cmap="gray")

# %%
plt.figure(figsize=(4, 4))
for i in range(16):
  new = decoder( np.random.randn(2).reshape((1,2)) )
  ax = plt.subplot(4, 4, i+1)
  plt.imshow(np.array(new[0]).reshape(28,28), vmin=0, vmax=1, cmap="gray")
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %% [markdown]
# # 연습문제

# %% [markdown]
# 1. 위의 코드에서 네트워크/훈련 파라메터를 적절히 조절하여 더 나은 결과를 얻을 수 있는지 확인하시오. Seed는 0으로 고정하며, 언급된 요소를 제외한 나머지 학습 파라미터는 기존 코드와 동일하게 학습하시오. <br>
# (1) 기존 모델의 n_hidden을 128로 변경 하였을 때 VAE 모델의 학습가능한 파라메터 수는 몇 개인가?<br>
# (2) (1)으로 변경된 모델을 학습 하였을 때, 평가 데이터의 MAE는 얼마인가?<br>
# (3) 생성이 얼마나 잘 되는지를 평가할 수 있는 방안을 고안하여 간략히 서술하시오.<br>

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(0)
np.random.seed(0)

# %%
# 네트워크 파라메터
input_size = 784
n_hidden = 128
latent_size = 2

# %%
input = tf.keras.Input(shape=(input_size,), name='input')
hidden = tf.keras.layers.Dense(
    n_hidden, activation='relu', name='hidden')(input)
z_mean = tf.keras.layers.Dense(latent_size, name='z_mean')(hidden)
z_var = tf.keras.layers.Dense(latent_size, name='z_var')(hidden)
z = tf.keras.layers.Lambda(sampling, name='z_sampling')([z_mean, z_var])
encoder = tf.keras.Model( input, [z_mean, z_var, z] )

# %%
encoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 784)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden (Dense)      │ (None, 128)       │    100,480 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │        258 │ hidden[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_var (Dense)       │ (None, 2)         │        258 │ hidden[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_sampling (Lambda) │ (None, 2)         │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_var[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 100,996 (394.52 KB)
#  Trainable params: 100,996 (394.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 디코더 입력은 latent 변수로부터
input = tf.keras.Input(shape=(latent_size,), name='input')
hidden = tf.keras.layers.Dense(
    n_hidden, activation='relu', name='hidden')(input)
# 출력은 인코더 입력과 같도록 학습하기 때문에 input_size가 사용
output = tf.keras.layers.Dense(
    input_size, activation='sigmoid',name='output')(hidden)
decoder = tf.keras.Model( input, output, name='decoder' )

# %%
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden (Dense)                  │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 784)            │       101,136 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,520 (396.56 KB)
#  Trainable params: 101,520 (396.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
input = tf.keras.Input(shape=(input_size,), name='input')
z = encoder(input)[2]  # [0]: z_mean, [1]: z_var, [2]: z
output = decoder(z)
model = tf.keras.Model(input, output, name='vae')

# 전체 파라미터 수 : 202516
model.summary()
# Out:
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ [(None, 2), (None, 2), │       100,996 │
# │                                 │ (None, 2)]             │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 784)            │       101,520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 202,516 (791.08 KB)
#  Trainable params: 202,516 (791.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer='adam',loss=vae_loss)

# %%
model.fit( xtrain, xtrain, epochs=20 )
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 74.5365
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 54.6421
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 53.5166
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 52.4679
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 51.7099
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 51.1447
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 50.7539
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 50.3936
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 50.1257
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 49.8468
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 49.6088
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 49.3740
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 49.1754
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 49.0078
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 48.8427
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 48.6830
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 48.5330
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 48.4471
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 48.3289
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 48.2022

# %%
r_xtest = model.predict(xtest)
test_mae = tf.keras.losses.mae(xtest,r_xtest)
print(f"MAE : {tf.reduce_mean(test_mae):.2f}")
print(f"MAE : {np.abs(xtest-r_xtest).mean():.2f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# MAE : 0.10
# MAE : 0.10

# %% [markdown]
# 진짜 데이터로 학습시킨 모델을 통해 새로 생성된 데이터를 분류하는 경우 분류가 잘 되는지 확인하여 생성의 성능을 확인할 수 있음. 또는 생성 데이터로만 모델을 학습하고 진짜 데이터를 분류하여 분류가 잘 되는지 확인하는 방법도 있음.
